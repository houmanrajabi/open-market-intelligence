# %%
import logging
from fomc_downloader import FOMCDownloader
from config import settings
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

downloader = FOMCDownloader(config=settings)
    
dates = downloader.get_date_range()

logging.info(f"Scanning from {settings.start_year} to {settings.end_year}...")

for date in dates:
    # Loop through the doc types defined in settings
    for doc_type in settings.target_docs:
        url = downloader.build_document_url(date, doc_type)
        filename = url.split('/')[-1]
        downloader.download_document(url, filename)
# Out:
# 2025-12-12 02:13:26,840 - INFO - Scanning from 2020 to 2025...
# 2025-12-12 02:14:19,086 - INFO - Downloaded: fomc_docs/fomcminutes20200129.pdf
# 2025-12-12 02:14:20,542 - INFO - Downloaded: fomc_docs/monetary20200129a1.pdf
# 2025-12-12 02:15:21,159 - INFO - Downloaded: fomc_docs/monetary20200303a1.pdf
# 2025-12-12 02:15:43,390 - INFO - Downloaded: fomc_docs/fomcminutes20200315.pdf
# 2025-12-12 02:15:45,459 - INFO - Downloaded: fomc_docs/monetary20200315a1.pdf
# 2025-12-12 02:15:59,035 - INFO - Downloaded: fomc_docs/monetary20200323a1.pdf
# 2025-12-12 02:17:05,576 - INFO - Downloaded: fomc_docs/fomcminutes20200429.pdf
# 2025-12-12 02:17:07,280 - INFO - Downloaded: fomc_docs/monetary20200429a1.pdf
